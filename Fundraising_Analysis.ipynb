# %%
# Add Matplotlib inline magic command
# %matplotlib inline

# Dpendencies and Setup
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Files to load
donor_data_to_load = "Resources/data_science_for_fundraising_donor_data.csv"
contact_reports_to_load = "Resources/data_science_for_fundraising_contact_reports.csv"
pawlus_data_to_load = "Resources/pawlus_small_sample.csv"

# %%
donor_df = pd.read_csv(donor_data_to_load)
donor_df.head(10)
# Out:
#    ID  ZIPCODE   AGE MARITAL_STATUS  GENDER MEMBERSHIP_IND ALUMNUS_IND  \
# 0   1  23187.0   NaN        Married  Female              N           N
# 1   2  77643.0  33.0            NaN  Female              N           Y
# 2   3      NaN   NaN        Married  Female              N           N
# 3   4  47141.0  31.0            NaN  Female              N           Y
# 4   5  92555.0  68.0            NaN  Female              N           N
# 5   6  95191.0  57.0            NaN    Male              N           N
# 6   7  90265.0   NaN            NaN    Male              N           N
# 7   8  67701.0   NaN        Married  Female              N           N
# 8   9  95972.0   NaN         Single  Uknown              N           N
# 9  10  49884.0   NaN        Married  Female              N           N
#
#   PARENT_IND HAS_INVOLVEMENT_IND WEALTH_RATING  ... CON_YEARS PrevFYGiving  \
# 0          N                   N           NaN  ...         1           $0
# ...

# %%
contact_df = pd.read_csv(contact_reports_to_load)
contact_df.head(10)
# Out:
#          Staff Name  Method      Date  \
# 0  Ann Marie Levier   Email   12/1/17
# 1  Ann Marie Levier   Email   12/1/17
# 2  Ann Marie Levier  Letter  11/30/17
# 3   Deborah Mettier   Phone  11/29/17
# 4  Ann Marie Levier  Letter  11/27/17
# 5  Ann Marie Levier  Letter  11/24/17
# 6  Ann Marie Levier  Letter  11/24/17
# 7       Bill Bamers   Visit  11/20/17
# 8    Carlos Bendiga   Email  10/30/17
# 9  Ann Marie Levier   Email  10/27/17
#
#                                              Summary Substantive  \
# 0  Sent Dominic an email asking for an update if ...           Y
# 1  Emailed Dr. Jonathan Winters, who have ties to...           Y
# 2  Sent Belinda an upgrade brochure, appeal lette...           Y
# 3  $50k to extend Kendrick Memorial Undergraduate...           Y
# 4  Sent upgrade brochure asking Jeffrey and Julie...           Y
# 5  Sent Marsha an leadership annual fund upgrade ...           Y
# 6  Sent upgrade brochure to Kenneth thanking them...           Y
# ...

# %%
pawlus_df = pd.read_csv(pawlus_data_to_load)
pawlus_df.head(10)
# Out:
#    coreid  aff_total coresex  coreprefyr Degree  \
# 0       1         11       F        2007     MS
# 1       2         24       M        1988    BBA
# 2       3         26       F        2012     BA
# 3       4         82       F        1972     BA
# 4       5          2       F        2000    MED
# 5       6          6       F        2007     BS
# 6       7          4       F        2005    MPA
# 7       8         31       M        2006    MPA
# 8       9          4       M        2005     BA
# 9      10         28       M        2014    MPA
#
#                              Major    fy14  donor
# 0                   Communications   100.0      1
# 1                       Accounting    25.0      1
# 2  English Language and Literature  8100.0      1
# 3                Political Science  2000.0      1
# 4                General Education    20.0      1
# 5                    Legal Studies    50.0      1
# 6            Public Administration    25.0      1
# ...
